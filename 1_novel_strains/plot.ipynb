# %%
library(ggplot2)
library(data.table)
theme_set(theme_bw())

# %%
tools = c('singlem', 'metaphlan', 'motus', 'kraken', 'sourmash', 'kaiju', 'map2b', 'metabuli')
# Tools that do not have the correct taxonomy are tested only at the domain level. eg. Kaiju has NCBI taxonomy and MAP2B uses GTDB v202, mOTUs sometimes has incompatible strings
correct_taxonomy_tools = c('singlem', 'metaphlan', 'kraken', 'sourmash', 'metabuli')

publication_names = data.table(
    tool = tools,
    publication_name = c('SingleM', 'MetaPhlAn', 'mOTUs', 'Kraken2', 'sourmash', 'Kaiju', 'MAP2B', 'Metabuli')
)
name_to_publication_name = function(names, correct_taxonomy_only=F){
    to_return = c()
    for (name in names){
        to_return = c(to_return, publication_names[tool==name]$publication_name)
    }
    if (correct_taxonomy_only){
        return(factor(to_return, levels=publication_names[tool %in% correct_taxonomy_tools]$publication_name))
    } else {
        return(factor(to_return, levels=publication_names$publication_name))
    }
}

# %%
# setwd('~/m/msingle/mess/124_singlem-benchmarking/1_novel_strains/')
base_dir = './'
# base_dir = 'full_run8/checkout/1_novel_strains/' # Directory created when run in local scratch through queuing system

# %%
communities = gsub('^','marine',as.character(0:9))
# communities = gsub('^','marine',as.character(6)) # debug
communities
# Out:
#  [1] "marine0" "marine1" "marine2" "marine3" "marine4" "marine5" "marine6"
#  [8] "marine7" "marine8" "marine9"

# %%
d1 = data.table(expand.grid(correct_taxonomy_tools, communities))
setnames(d1, c('tool', 'community'))
d1[1:3]
# Out:
#   tool      community
# 1 singlem   marine0
# 2 metaphlan marine0
# 3 kraken    marine0

# %%
# output_singlem/opal/GCA_022615805.1_genomic.opal_report
readit = function(tool, community){
    to_read = paste(base_dir,'output_',tool,sep='','/opal/',community,'.opal_report')
    # print(to_read)
    return(fread(to_read))
}
d2 = d1[, readit(tool, community), by=list(tool,community)]
d2[1:3]
# Out:
#   tool    community tool          rank    metric               sample   value
# 1 singlem marine0   Gold standard kingdom Bray-Curtis distance SAMPLEID 0
# 2 singlem marine0   Gold standard phylum  Bray-Curtis distance SAMPLEID 0
# 3 singlem marine0   Gold standard class   Bray-Curtis distance SAMPLEID 0

# %%
dim(d2)
# Out:
# [1] 9100    7

# %%
setnames(d2, c('tool','community','blah','rank','metric','sample','value'))
d3 = d2[blah != 'Gold standard'][,.(tool, community, rank, metric, value)]
d3[1:3]
dim(d3)
# Out:
#   tool    community rank    metric               value
# 1 singlem marine0   kingdom Bray-Curtis distance 0.001544949
# 2 singlem marine0   phylum  Bray-Curtis distance 0.013298170
# 3 singlem marine0   class   Bray-Curtis distance 0.017636477
# [1] 4550    5

# %%
fwrite(d3, 'accuracy_results.csv')

# %%
bc = d3[metric=='Bray-Curtis distance']
dim(bc)
bc[1:10]
# Out:
# [1] 350   5
#    tool      community rank    metric               value
# 1  singlem   marine0   kingdom Bray-Curtis distance 0.001544949
# 2  singlem   marine0   phylum  Bray-Curtis distance 0.013298170
# 3  singlem   marine0   class   Bray-Curtis distance 0.017636477
# 4  singlem   marine0   order   Bray-Curtis distance 0.021762617
# 5  singlem   marine0   family  Bray-Curtis distance 0.029771765
# 6  singlem   marine0   genus   Bray-Curtis distance 0.040311086
# 7  singlem   marine0   species Bray-Curtis distance 0.164574594
# 8  metaphlan marine0   kingdom Bray-Curtis distance 0.000429368
# 9  metaphlan marine0   phylum  Bray-Curtis distance 0.053544980
# 10 metaphlan marine0   class   Bray-Curtis distance 0.065888945

# %%
orders = c('kingdom','phylum','class','order','family','genus','species')
bc[, rank := factor(rank, levels=orders)]
bc[1:3]
# Out:
#   tool    community rank    metric               value
# 1 singlem marine0   kingdom Bray-Curtis distance 0.001544949
# 2 singlem marine0   phylum  Bray-Curtis distance 0.013298170
# 3 singlem marine0   class   Bray-Curtis distance 0.017636477

# %%
average_bc = bc[tool %in% correct_taxonomy_tools][, list(mn = mean(value)), by=list(tool)][order(mn)]
average_bc
# Out:
#   tool      mn
# 1 singlem   0.04440262
# 2 metaphlan 0.10840302
# 3 kraken    0.16342854
# 4 sourmash  0.18185493
# 5 metabuli  0.27421308

# %%
bcc = bc[tool %in% correct_taxonomy_tools]
bcc[, tool2 := name_to_publication_name(tool, correct_taxonomy_only=T)]

# %%
# Remove figure legend title, and put the legend in bottom left of plot, with a bounding box
qplot(data=bcc, rank, value, ylim=c(0.6,0), geom='boxplot', colour=tool, ylab='Bray-Curtis dissimilarity') +
   theme(axis.text.x = element_text(angle = 45, hjust = 1)) +
   theme(legend.title=element_blank()) +
   theme(legend.position=c(0.2,0.2)) +
   theme(legend.background = element_rect(colour = "black", size = 0.3))
# Out:
# Warning message:
# “`qplot()` was deprecated in ggplot2 3.4.0.”
# Warning message:
# “A numeric `legend.position` argument in `theme()` was deprecated in ggplot2
# 3.5.0.
# ℹ Please use the `legend.position.inside` argument of `theme()` instead.”
# Warning message:
# “The `size` argument of `element_rect()` is deprecated as of ggplot2 3.4.0.
# ℹ Please use the `linewidth` argument instead.”
# Warning message:
# “Removed 3 rows containing non-finite outside the scale range
# (`stat_boxplot()`).”
# plot without title

# %%
# What is the comparison between tools at the kingdom level specifically?
qplot(data=bcc[rank=='kingdom'], rank, value, geom='boxplot', colour=tool, ylab='Bray-Curtis dissimilarity') +
  theme(axis.text.x = element_text(angle = 45, hjust = 1)) +
  theme(legend.title=element_blank()) +
  theme(legend.position=c(0.2,0.2)) +
  theme(legend.background = element_rect(colour = "black", size = 0.3))
bcc[rank=='kingdom'][,.(mn = mean(value)), by=tool]
# Out:
#   tool      mn
# 1 singlem   0.002315230
# 2 metaphlan 0.002046207
# 3 kraken    0.005839309
# 4 sourmash  0.005193939
# 5 metabuli  0.006287491
# plot without title

# %%
# How much better is singlem than the next best tool?
means = bcc[rank=='species', list(mn = mean(value)), by=tool][order(-mn)]
means
means[tool=='singlem', mn] - means[tool!='singlem', min(mn)]
# Out:
#   tool      mn
# 1 metabuli  0.5845918
# 2 sourmash  0.3115963
# 3 kraken    0.2686107
# 4 metaphlan 0.2196380
# 5 singlem   0.1546571
# [1] -0.06498093

# %%
# write out bc
fwrite(bcc, 'bray-curtis.csv', sep='\t')

# %% [markdown]
# # Runtime comparison

# %%
# thread_numbers = as.character(c(1,8,32))
thread_numbers = as.character(c(1))

# %%
# DEBUG - set to 32 threads so to get a preliminary answer
# thread_numbers = c(32)

# %%
r1 = data.table(expand.grid(correct_taxonomy_tools, thread_numbers, communities))
setnames(r1, c('tool', 'threads', 'community'))
r1 = r1[tool != 'coverm' | threads == '32']
r1[1:3]
# Out:
#   tool      threads community
# 1 singlem   1       marine0
# 2 metaphlan 1       marine0
# 3 kraken    1       marine0

# %%
r1[tool=='kracken', tool := 'kraken']
reed = function(tool,threads,community){
    # print(x)
    # f = paste(base_dir,'benchmarks/',x$tool,'/',x$community,'-',x$threads,'threads.benchmark',sep='')
    f = paste(base_dir,'benchmarks/',tool,'/',community,'-',threads,'threads.benchmark',sep='')
    # print(f)
    return(fread(f))
}
r2 = r1[, reed(tool,threads,community), by=list(tool,threads,community)]
r2[, mature_s := max(s, cpu_time), by=.(tool,threads,community)] # Use the maximum of the two times, because some methods use >1 thread even though they are supposedly single-threaded
getwd()
r2[1:3]
# Out:
# [1] "/mnt/hpccs01/home/lamber22/git/singlem-benchmarking/1_novel_strains"
#   tool      threads community s         h:m:s   max_rss   max_vms   max_uss
# 1 singlem   1       marine0    1338.972 0:22:18   1881.88   4465.95   1858.06
# 2 metaphlan 1       marine0   16285.446 4:31:25  17485.74  18395.73  17459.30
# 3 kraken    1       marine0    1511.075 0:25:11 294238.54 294256.45 294236.07
#   max_pss   io_in     io_out mean_load cpu_time mature_s
# 1   1873.79    477.96 581.92 81.10      1125.55  1338.972
# 2  17468.78  16905.36 116.47 98.64     16035.02 16285.446
# 3 294236.22 294190.58   0.01 63.45       959.04  1511.075

# %%
r2[,.(minutes=mean(mature_s/60), minutes_sd=sd(mature_s/60), mean_mem = mean(max_rss), sd_mem = sd(max_rss)), by=list(tool,threads)]
# Out:
#   tool      threads minutes   minutes_sd mean_mem   sd_mem
# 1 singlem   1        25.67569  3.691485    2040.639  113.981976
# 2 metaphlan 1       271.13270 26.743662   17478.295    4.478584
# 3 kraken    1        25.48282  1.548824  294241.241   23.255480
# 4 sourmash  1        31.21783  5.478572    2949.947  421.285924
# 5 metabuli  1       219.90423 11.593443  120740.785 9223.456300

# %%
qplot(data=r2, threads, mature_s/60, geom='boxplot', fill=tool, ylab='Time (minutes)', main='Runtime on community of novel strains') +
  theme(axis.text.x = element_text(angle = 45, hjust = 1))
# Out:
# plot without title

# %%
r3 = r2[, .(mean_s = mean(mature_s)), by=list(tool,threads)]
# r3
qplot(data=r3, as.numeric(threads), mean_s/60, geom='point', ylab='Time (minutes)', xlab='# threads', main='Runtime on community of novel strains', colour=tool) +
  geom_line() +
  scale_x_continuous(breaks=c(1,2,3), labels=c(1,8,32))
# Out:
# `geom_line()`: Each group consists of only one observation.
# ℹ Do you need to adjust the group aesthetic?
# plot without title

# %%
# RAM
r4 = r2[, .(mean_mem = mean(max_rss)), by=list(tool,threads)]
qplot(data=r4, as.numeric(threads), mean_mem/1000, geom='point', ylab='Memory (GB)', xlab='# threads', main='Memory usage on community of novel strains', colour=tool) +
  geom_line() +
  scale_x_continuous(breaks=c(1,2,3), labels=c(1,8,32))
# Out:
# `geom_line()`: Each group consists of only one observation.
# ℹ Do you need to adjust the group aesthetic?
# plot without title

# %%
r4
# Out:
#   tool      threads mean_mem
# 1 singlem   1         2040.639
# 2 metaphlan 1        17478.295
# 3 kraken    1       294241.241
# 4 sourmash  1         2949.947
# 5 metabuli  1       120740.785

# %%
# How much faster than MetaPhlAn & Metabuli is SingleM?
r3[tool=='singlem' & threads==1]$mean_s / r3[tool %in% c('metaphlan') & threads==1]$mean_s* 100
r3[tool=='singlem' & threads==1]$mean_s / r3[tool %in% c('metabuli') & threads==1]$mean_s* 100
r4[tool=='singlem' & threads==1]$mean_mem / r4[tool %in% c('metaphlan') & threads==1]$mean_mem * 100
r4[tool=='singlem' & threads==1]$mean_mem / r4[tool %in% c('metabuli') & threads==1]$mean_mem * 100
# Out:
# [1] 9.469789
# [1] 11.67585
# [1] 11.67527
# [1] 1.690099

# %%
## Commented out because it takes a while to run

# Reads per minute
read_counts = data.table(community=communities)
read_counts2 = read_counts[, fread(cmd=paste('zcat local_reads/',community,'.1.fq.gz | wc -l',sep='')), by=community]
read_counts2

rcm = merge(r2[threads==1], read_counts2, by='community')
rcm[, rpm := (V1/4)/s*60 *2] # times 2 because we only have half the reads in count
rcm[1:3]
# Out:
# Warning message in fread(cmd = paste("zcat local_reads/", community, ".1.fq.gz | wc -l", :
# “File '/tmp/RtmpJYxkwd/file35d2dd7982381c' has size 0. Returning a NULL data.table.”
#   community V1
# 1 marine1   87521336
# 2 marine2   90556212
# 3 marine3   90923712
# 4 marine4   94395772
# 5 marine5   98855308
# 6 marine6   83439884
# 7 marine7   89833484
# 8 marine8   90915132
# 9 marine9   79140080
#   community tool      threads s         h:m:s   max_rss   max_vms   max_uss
# 1 marine1   singlem   1        1349.174 0:22:29   1881.95   4423.79   1873.23
# 2 marine1   metaphlan 1       15550.061 4:19:10  17476.82  18395.72  17437.06
# 3 marine1   kraken    1        1469.864 0:24:29 294257.98 294274.23 294255.23
#   max_pss   io_in     io_out mean_load cpu_time mature_s  V1       rpm
# 1   1884.95   4826.23 646.21 82.16      1155.93  1349.174 87521336 1946108.9
# 2  17449.87   8176.43 107.17 98.56     15325.66 15550.061 87521336  168850.8
# 3 294255.73 176528.23   0.01 61.36       902.49  1469.864 87521336 1786315.1

# %%
# Write rc3
fwrite(r2, 'runtime.csv', sep='\t')

# %%
r2[1:3]
# Out:
#   tool      threads community s         h:m:s   max_rss   max_vms   max_uss
# 1 singlem   1       marine0    1338.972 0:22:18   1881.88   4465.95   1858.06
# 2 metaphlan 1       marine0   16285.446 4:31:25  17485.74  18395.73  17459.30
# 3 kraken    1       marine0    1511.075 0:25:11 294238.54 294256.45 294236.07
#   max_pss   io_in     io_out mean_load cpu_time mature_s
# 1   1873.79    477.96 581.92 81.10      1125.55  1338.972
# 2  17468.78  16905.36 116.47 98.64     16035.02 16285.446
# 3 294236.22 294190.58   0.01 63.45       959.04  1511.075

# %%
# Write for supp data
fwrite(
    r2[threads==1, .(community, tool=name_to_publication_name(tool), runtime_seconds=s, max_rss)],
    'runtimes_readable.csv')

# %% [markdown]
# # Full set of stats of each method

# %%
s1 = dcast(d3, tool+rank~metric, value.var='value', fun.aggregate=mean)

s1 = s1[tool %in% correct_taxonomy_tools]
s1[, tool2 := name_to_publication_name(tool, correct_taxonomy_only=T)]
s1[, tool := tool2]
s1[, tool2 := NULL]

# dcast(d3[metric %in% non_ranked_metrics], tool~metric, value.var='value', fun.aggregate=mean)

s1[, rank := factor(rank, levels=orders)]
s1 = s1[order(rank, tool)]
s1[1:3]
fwrite(s1, 'opal_summary.csv', sep='\t')
# Out:
#   tool      rank    Bray-Curtis distance Completeness F1 score False negatives
# 1 SingleM   kingdom 0.002315230          1            1        0
# 2 MetaPhlAn kingdom 0.002046207          1            1        0
# 3 Kraken2   kingdom 0.005839309          1            1        0
#   False positives Jaccard index L1 norm error Purity Shannon diversity
# 1 0               1             0.004630461   1      NaN
# 2 0               1             0.004092413   1      NaN
# 3 0               1             0.011678618   1      NaN
#   Shannon equitability Sum of abundances Taxon counts True positives
# 1 NaN                  NaN               NaN          2
# 2 NaN                  NaN               NaN          2
# 3 NaN                  NaN               NaN          2
#   Unweighted UniFrac (CAMI) Unweighted UniFrac error Weighted UniFrac (CAMI)
# 1 NaN                       NaN                      NaN
# 2 NaN                       NaN                      NaN
# 3 NaN                       NaN                      NaN
#   Weighted UniFrac error
# 1 NaN
# 2 NaN
# 3 NaN

# %% [markdown]
# # Relationship between relative abundance and accuracy

# %%
# tool_profiles[4:5][, fread(paste(base,'/output_',tool,'/',tool,'/',community,'.profile',sep=''))[,.(sample,coverage=as.numeric(coverage),taxonomy)], by=list(tool,community)]

# %%
base = base_dir #'/mnt/hpccs01/work/microbiome/msingle/mess/124_singlem-benchmarking/1_novel_strains/full_run1/checkout/1_novel_strains/'
# base = './'

truth_profiles = data.table(community=communities)
truth_profiles2 = truth_profiles[, fread(paste(base,'/truths/',community,'.condensed',sep='')), by=community]
truth_profiles2[, sample := NULL]
setnames(truth_profiles2, 'coverage', 'true_coverage')

tool_profiles = data.table(expand.grid(correct_taxonomy_tools, communities))
setnames(tool_profiles, c('tool','community'))
# Metabuli profiles have integer coverage, so need to convert to numeric
tool_profiles2 = tool_profiles[, fread(paste(base,'/output_',tool,'/',tool,'/',community,'.profile',sep=''))[,.(sample,coverage=as.numeric(coverage),taxonomy)], by=list(tool,community)]
tool_profiles2[, sample := NULL]
setnames(tool_profiles2, 'coverage', 'tool_coverage')
tool_profiles2[, taxonomy := gsub('Root;','',gsub('; ',';',taxonomy))]

# Kraken has filled profiles, so remove all except species annotations
tool_profiles3 = rbind(
    tool_profiles2[tool != 'kraken'],
    tool_profiles2[tool == 'kraken' & taxonomy %like% 's__']
)
tool_profiles3[tool=='kraken'][1:5]
# cartesian product so the all = T works for each tool
community_tool = data.table(expand.grid(tools, communities))
setnames(community_tool, c('tool','community'))
truth_profiles3 = merge(truth_profiles2, community_tool, all=T, allow.cartesian=T)
# truth_profiles3

m = merge(truth_profiles3, tool_profiles3, by=c('taxonomy','community','tool'), all=T)

m[is.na(tool_coverage), tool_coverage := 0]
m[is.na(true_coverage), true_coverage := 0]
# Out:
#   tool   community tool_coverage
# 1 kraken marine0   0.04243
# 2 kraken marine0   0.02739
# 3 kraken marine0   0.00434
# 4 kraken marine0   0.00413
# 5 kraken marine0   0.00404
#   taxonomy
# 1 d__Bacteria;p__Proteobacteria;c__Gammaproteobacteria;o__Pseudomonadales;f__Pseudomonadaceae;g__Pseudomonas_E;s__Pseudomonas_E soli
# 2 d__Bacteria;p__Proteobacteria;c__Gammaproteobacteria;o__Pseudomonadales;f__Pseudomonadaceae;g__Pseudomonas_E;s__Pseudomonas_E sp019139675
# 3 d__Bacteria;p__Proteobacteria;c__Gammaproteobacteria;o__Pseudomonadales;f__Pseudomonadaceae;g__Pseudomonas_E;s__Pseudomonas_E sp003013355
# 4 d__Bacteria;p__Proteobacteria;c__Gammaproteobacteria;o__Pseudomonadales;f__Pseudomonadaceae;g__Pseudomonas_E;s__Pseudomonas_E lactis
# 5 d__Bacteria;p__Proteobacteria;c__Gammaproteobacteria;o__Pseudomonadales;f__Pseudomonadaceae;g__Pseudomonas_E;s__Pseudomonas_E mosselii

# %%
# Just for SingleM
qplot(data=m[tool=='singlem' & tool_coverage < 50][grep('s__',taxonomy)], true_coverage, tool_coverage, geom='point', xlab='True coverage', ylab='SingleM coverage', main='Coverage of novel strains in all known species benchmarks', alpha=I(1/5)) +
  geom_abline(intercept=0, slope=1) +
  scale_x_sqrt() +
  scale_y_sqrt()
# Out:
# plot without title

# %%
m[tool=='kraken'][grep('s__',taxonomy)][community=='marine6'][order(-tool_coverage)][1:3]
# Out:
#   taxonomy
# 1 d__Bacteria;p__Proteobacteria;c__Gammaproteobacteria;o__Enterobacterales;f__Enterobacteriaceae;g__Kluyvera;s__Kluyvera intermedia
# 2 d__Bacteria;p__Proteobacteria;c__Alphaproteobacteria;o__Rhizobiales;f__Rhizobiaceae;g__Rhizobium;s__Rhizobium sophoriradicis
# 3 d__Bacteria;p__Proteobacteria;c__Gammaproteobacteria;o__Burkholderiales;f__Burkholderiaceae;g__Paraburkholderia;s__Paraburkholderia terricola
#   community tool   true_coverage tool_coverage
# 1 marine6   kraken 63.7534       0.05043
# 2 marine6   kraken 37.7800       0.03884
# 3 marine6   kraken 23.9494       0.02667

# %% [markdown]
# # Read in ANI of each shadow genome to GTDB reps

# %%
shadow_anis = fread('../shadow_vs_gtdb.skani.csv', sep='\t')
shadow_anis = shadow_anis[ANI>90][,.(
    rep=gsub('_genomic.*','', gsub('.*/','',Ref_file)),
    shadow=gsub('.fna','', gsub('.*/','',Query_file)),
    ANI,
    Align_fraction_query
)]
shadow_anis = shadow_anis[order(-ANI)][, .SD[1], by=shadow]
dim(shadow_anis)
shadow_anis[1:3]
stopifnot(nrow(shadow_anis) == 3000)
# Out:
# [1] 3000    4
#   shadow          rep             ANI Align_fraction_query
# 1 GCA_002210125.1 GCF_002797755.1 100 100.00
# 2 GCA_016860585.1 GCA_016860565.1 100  99.00
# 3 GCA_900753675.1 GCA_900549975.1 100  83.68

# %%
communities = gsub('^','marine',as.character(0:9))
# communities = gsub('^','marine',as.character(6)) # debug
communities_df = data.table(community=communities)
communities_df
# Out:
#    community
# 1  marine0
# 2  marine1
# 3  marine2
# 4  marine3
# 5  marine4
# 6  marine5
# 7  marine6
# 8  marine7
# 9  marine8
# 10 marine9

# %%
# Read the genome-wise from each community
genomewise_communities = communities_df[,fread(paste('truths/',community,'.genomewise.csv',sep='')), by=community]
genomewise_communities[1:3]
dim(genomewise_communities)
# Out:
#   community accession          coverage
# 1 marine0   RS_GCF_001953075.1 2.12834
# 2 marine0   RS_GCF_003815695.1 1.83878
# 3 marine0   RS_GCF_013321855.1 2.42345
#   fasta
# 1 /mnt/hpccs01/home/lamber22/git/singlem-benchmarking/reference_genomes/shadow/GCF_001953075.1.fna
# 2 /mnt/hpccs01/home/lamber22/git/singlem-benchmarking/reference_genomes/shadow/GCF_003815695.1.fna
# 3 /mnt/hpccs01/home/lamber22/git/singlem-benchmarking/reference_genomes/shadow/GCF_013321855.1.fna
#   taxonomy
# 1 d__Bacteria;p__Proteobacteria;c__Gammaproteobacteria;o__Pseudomonadales;f__Halieaceae;g__Halioglobus;s__Halioglobus lutimaris
# 2 d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__Flavobacteriales;f__Weeksellaceae;g__Chryseobacterium;s__Chryseobacterium carnipullorum
# 3 d__Bacteria;p__Proteobacteria;c__Alphaproteobacteria;o__Rhizobiales;f__Rhizobiaceae;g__Rhizobium;s__Rhizobium rhizogenes
# [1] 4694    5

# %%
highest_per_community = genomewise_communities[order(-coverage)][,.SD[1],by=list(community,taxonomy)]
dim(highest_per_community)
# Out:
# [1] 4556    5

# %%
highest_per_community[, shadow := gsub('^.._','',accession)]
shadow_merge = merge(highest_per_community[,.(community,shadow,taxonomy)], shadow_anis, by='shadow')
shadow_merge[1:3]
# Out:
#   shadow          community
# 1 GCA_000191565.1 marine4
# 2 GCA_000191565.1 marine6
# 3 GCA_000191565.1 marine7
#   taxonomy
# 1 d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__Flavobacteriales;f__Weeksellaceae;g__Riemerella;s__Riemerella anatipestifer
# 2 d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__Flavobacteriales;f__Weeksellaceae;g__Riemerella;s__Riemerella anatipestifer
# 3 d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__Flavobacteriales;f__Weeksellaceae;g__Riemerella;s__Riemerella anatipestifer
#   rep             ANI   Align_fraction_query
# 1 GCF_000252855.1 99.59 98.33
# 2 GCF_000252855.1 99.59 98.33
# 3 GCF_000252855.1 99.59 98.33

# %%
# All tools
# First convert to relabund
m[, tool_coverage_relabund := tool_coverage/sum(tool_coverage)*100, by=list(tool, community)]
m[, true_coverage_relabund := true_coverage/sum(true_coverage)*100, by=list(tool, community)]

m = m[tool %in% correct_taxonomy_tools]
m[, tool2 := name_to_publication_name(tool, correct_taxonomy_only=T)]

# %%
m_species = m[grep('s__',taxonomy)]
shadow_merge[, taxonomy := gsub('; ',';', taxonomy)]

shadow_merge[, com_tax := paste(community, taxonomy)]
m_species[, com_tax := paste(community, taxonomy)]

m_species2 = merge(m_species, shadow_merge[,.(com_tax, ANI)], by='com_tax')

original_width_height = c(getOption('repr.plot.width'), getOption('repr.plot.height'))
options(repr.plot.width=8, repr.plot.height=13)

m_species2[, ANI98_str := 'ANI < 97%']
m_species2[ANI >= 97, ANI98_str := 'ANI >= 97%']

qplot(data=m_species2, true_coverage_relabund, tool_coverage_relabund, geom='point', xlab='True relative abundance (%)', ylab='Predicted relative abundance (%)', alpha=I(1/10)) + geom_abline(intercept=0, slope=1, colour='red')+scale_x_sqrt()+scale_y_sqrt()+facet_grid(tool2~ANI98_str, scales='free')
options(repr.plot.width=original_width_height[1], repr.plot.height=original_width_height[2])
# Out:
# Error: object 'shadow_merge' not found
# Traceback:

# %%
# Quantify outside of 98% for SingleM
m_species2[tool2=='SingleM'][,.(mean(sqrt((true_coverage-tool_coverage)**2))), by=ANI<98]
# Out:
#   ANI   V1
# 1 FALSE 0.6807065
# 2  TRUE 1.5361983

# %%
# What's with the 20+ coverage genome?

# marine0 = fread(paste(base,'truths/marine0.condensed',sep=''))
# marine0[, sample := 'marine0']
# setnames(marine0, 'coverage', 'true_coverage')
# singlem_marine0 = fread(paste(base,'output_singlem/singlem/marine0.profile',sep=''))
# setnames(singlem_marine0, 'coverage', 'singlem_coverage')
# singlem_marine0[, taxonomy := gsub('Root;','',gsub('; ',';',taxonomy))]
# # singlem_marine0[grep('s__',taxonomy)][1:3]

# m[true_coverage > 20 & singlem_coverage ==0]
# singlem_marine0[grep('g__Pseudomonas_E',taxonomy)]
# # => So it backed off to species level for some reason. Unsure why.

# %%
# Fraction of genomes which were missed at each binned coverage levels
# m[, .(missed = sum(singlem_coverage==0)/.N*100, .N), by=.(cut(true_coverage, breaks=c(0,2,4,6,8,10,20,40,1000)))][order(cut)]

# %%
# How well does genus level rescue some of the missing genomes? First need to remake the table with genus level, annoying since kraken profiles are filled, when the rest aren't.

# Kraken has filled profiles, so remove all except species annotations
tool_profiles3_genus = rbind(
    tool_profiles2[tool != 'kraken'],
    tool_profiles2[tool == 'kraken' & taxonomy %like% 'g__']
)
tool_profiles3_genus[tool=='kraken'][1:5]

m_genus = merge(truth_profiles3, tool_profiles3_genus, by=c('taxonomy','community','tool'), all=T)

m_genus[is.na(tool_coverage), tool_coverage := 0]
m_genus[is.na(true_coverage), true_coverage := 0]

m_genus[1:3]

m_genus[, genus_and_up := gsub(';s__.*','',taxonomy)]

# m[grep('g__',taxonomy)][1:10]
m2_genus = m_genus[, .(tool_coverage=sum(tool_coverage), true_coverage=sum(true_coverage)), by=.(community, genus_and_up, tool)]

m2_genus[grep('g__',genus_and_up)][tool=='kraken' & true_coverage > 0][1:3]
# Out:
#   tool   community tool_coverage
# 1 kraken marine0   0.14710
# 2 kraken marine0   0.00449
# 3 kraken marine0   0.00403
# 4 kraken marine0   0.00233
# 5 kraken marine0   0.00002
#   taxonomy
# 1 d__Bacteria;p__Proteobacteria;c__Gammaproteobacteria;o__Pseudomonadales;f__Pseudomonadaceae;g__Pseudomonas_E
# 2 d__Bacteria;p__Proteobacteria;c__Gammaproteobacteria;o__Pseudomonadales;f__Pseudomonadaceae;g__Pseudomonas
# 3 d__Bacteria;p__Proteobacteria;c__Gammaproteobacteria;o__Pseudomonadales;f__Pseudomonadaceae;g__Pseudomonas_A
# 4 d__Bacteria;p__Proteobacteria;c__Gammaproteobacteria;o__Pseudomonadales;f__Pseudomonadaceae;g__Pseudomonas_F
# 5 d__Bacteria;p__Proteobacteria;c__Gammaproteobacteria;o__Pseudomonadales;f__Pseudomonadaceae;g__Pseudomonas_R
#   taxonomy   community tool     true_coverage tool_coverage
# 1 d__Archaea marine0   singlem  0               1.910
# 2 d__Archaea marine0   sourmash 0               0.005
# 3 d__Archaea marine0   metabuli 0             499.000
#   community
# 1 marine0
# 2 marine1
# 3 marine2
#   genus_and_up
# 1 d__Archaea;p__Halobacteriota;c__Archaeoglobi;o__Archaeoglobales;f__JdFR-42;g__JdFR-42
# 2 d__Archaea;p__Halobacteriota;c__Archaeoglobi;o__Archaeoglobales;f__JdFR-42;g__JdFR-42
# 3 d__Archaea;p__Halobacteriota;c__Archaeoglobi;o__Archaeoglobales;f__JdFR-42;g__JdFR-42
#   tool   tool_coverage true_coverage
# 1 kraken 0.00039       1.18832
# 2 kraken 0.00056       1.67278
# 3 kraken 0.00047       1.45378

# %%
m2_genus[, tool_coverage_relabund := tool_coverage/sum(tool_coverage)*100, by=list(tool, community)]
m2_genus[, true_coverage_relabund := true_coverage/sum(true_coverage)*100, by=list(tool, community)]

m2_genus = m2_genus[tool %in% correct_taxonomy_tools]
m2_genus[, tool2 := name_to_publication_name(tool, correct_taxonomy_only=T)]

original_width_height = c(getOption('repr.plot.width'), getOption('repr.plot.height'))
options(repr.plot.width=8, repr.plot.height=10)
qplot(data=m2_genus[grep('g__',genus_and_up)], true_coverage_relabund, tool_coverage_relabund, geom='point', xlab='True relative abundance (%)', ylab='Predicted relative abundance of genus (%)', alpha=I(1/10)) + geom_abline(intercept=0, slope=1, colour='red')+scale_x_sqrt()+scale_y_sqrt()+facet_wrap(~tool2, ncol=2, scales='free')
options(repr.plot.width=original_width_height[1], repr.plot.height=original_width_height[2])
# Out:
# plot without title

# %%
# Percent error at the species level for each tool
# m[1:3]
m_error = m_species[true_coverage>0 & tool_coverage>0]
m_error[, error := abs(true_coverage_relabund - tool_coverage_relabund)/true_coverage_relabund*100]

options(repr.plot.width=8, repr.plot.height=8)
qplot(data=m_error, true_coverage, error, geom='point', xlab='True coverage', ylab='Percent error (%)', alpha=I(1/10))+scale_x_sqrt()+scale_y_sqrt()+facet_wrap(~tool2, ncol=2)+geom_smooth(se=F)
# Out:
# `geom_smooth()` using method = 'gam' and formula = 'y ~ s(x, bs = "cs")'
# plot without title

# %% [markdown]
# # What fraction of singlem profiles are assigned to the species level?

# %%
# m
assigned = m[tool2=='SingleM'][,sum(.SD[grep('s__',taxonomy)]$tool_coverage_relabund),by=community]
assigned
mean(assigned$V1)
sd(assigned$V1)
# Out:
#    community V1
# 1  marine0   88.10433
# 2  marine1   86.47792
# 3  marine2   89.04161
# 4  marine3   84.54293
# 5  marine4   89.37838
# 6  marine5   86.37931
# 7  marine6   88.50804
# 8  marine7   87.59271
# 9  marine8   88.90587
# 10 marine9   86.77871
# [1] 87.57098
# [1] 1.519725

# %% [markdown]
# # How many species are in each gold standard?

# %%
coverages = data.table(number=0:9)
coverages2 = coverages[, fread(paste('coverage_definitions/coverage',number,'.tsv',sep='')), by=number]
setnames(coverages2, c('number','genome','coverage'))
mean(coverages2[grep('Otu',genome)][coverage>0][,.N,by=number]$N)
coverages2[grep('Otu',genome)][coverage>0]
# Out:
# [1] 469.4
#      number genome   coverage
# 1    0      Otu520.0  2.12834
# 2    0      Otu634.0  1.83878
# 3    0      Otu483    2.42345
# 4    0      Otu2487   1.56681
# 5    0      Otu2446   1.33722
# 6    0      Otu980    3.43963
# 7    0      Otu1219   1.34402
# 8    0      Otu2448   2.10658
# 9    0      Otu489.0  1.57037
# 10   0      Otu1596   1.33922
# 11   0      Otu713    1.84970
# 12   0      Otu1330   1.33674
# 13   0      Otu1961   1.57107
# 14   0      Otu1892   1.33795
# 15   0      Otu1896   1.32098
# 16   0      Otu523    2.43417
# 17   0      Otu526    1.33993
# 18   0      Otu800.0  1.84415
# 19   0      Otu249.0  4.55348
# 20   0      Otu1283   1.34145
# 21   0      Otu453    4.15483
# 22   0      Otu88.0  15.83670
# 23   0      Otu245.0  1.57260
# 24   0      Otu80.0   5.32995
# 25   0      Otu315.0  1.83476
# 26   0      Otu1769   1.33760
# 27   0      Otu331.0  1.33234
# 28   0      Otu796    1.83154
# 29   0      Otu241.0  1.84318
# 30   0      Otu279    1.33175
# ⋮    ⋮      ⋮        ⋮
# 4665 9      Otu576    1.56797
# 4666 9      Otu1000   2.74135
# 4667 9      Otu218    4.16711
# 4668 9      Otu961    2.11477
# 4669 9      Otu211   10.15340
# 4670 9      Otu965    1.33329
# 4671 9      Otu199.0  2.42355
# 4672 9      Otu960.0  2.42534
# 4673 9      Otu1723   1.34159
# 4674 9      Otu53.0   6.51875
# 4675 9      Otu214.0  4.93480
# 4676 9      Otu364    1.32042
# 4677 9      Otu610    1.33247
# 4678 9      Otu368    1.33212
# 4679 9      Otu132    4.54816
# 4680 9      Otu136    6.52026
# 4681 9      Otu139    2.42539
# 4682 9      Otu203    1.83143
# 4683 9      Otu846.0  1.83450
# 4684 9      Otu10    28.79330
# 4685 9      Otu11    50.35420
# 4686 9      Otu2438   1.83987
# 4687 9      Otu47.0   7.72485
# 4688 9      Otu1264   1.34308
# 4689 9      Otu399.0  1.33005
# 4690 9      Otu235.0  8.53199
# 4691 9      Otu2087   1.31837
# 4692 9      Otu497.0  1.17923
# 4693 9      Otu497.1  2.64262
# 4694 9      Otu180    1.83823

# %% [markdown]
# # Actual coverage estimation investigation

# %%
# What is the reason for the lower F1 score (really completeness) of SingleM on CAMI ?

# Take marine7 as an example
# Read gold standard condensed
gs = fread('truths/marine7.condensed')[order(-coverage)]
gs[, taxonomy := gsub(';','; ',taxonomy)]
sm = fread('output_singlem/singlem/marine7.profile')[order(-coverage)]
gs[1:3]

sm_species = sm[grep('s__', taxonomy)][order(-coverage)]
sm_species[1:3]
# Out:
#   sample        coverage
# 1 coverage7.tsv 134.5270
# 2 coverage7.tsv  92.0649
# 3 coverage7.tsv  75.6696
#   taxonomy
# 1 d__Bacteria; p__Firmicutes_B; c__Desulfotomaculia; o__Desulfotomaculales; f__Pelotomaculaceae; g__Pelotomaculum_C; s__Pelotomaculum_C schinkii
# 2 d__Bacteria; p__Actinobacteriota; c__Actinomycetia; o__Nanopelagicales; f__CAIYMF01; g__WLRQ01; s__WLRQ01 sp903918645
# 3 d__Bacteria; p__Firmicutes_A; c__Clostridia; o__Lachnospirales; f__Lachnospiraceae; g__RGIG1934; s__RGIG1934 sp017396555
#   sample    coverage
# 1 marine7.1 135.56
# 2 marine7.1  88.34
# 3 marine7.1  36.09
#   taxonomy
# 1 Root; d__Bacteria; p__Firmicutes_B; c__Desulfotomaculia; o__Desulfotomaculales; f__Pelotomaculaceae; g__Pelotomaculum_C; s__Pelotomaculum_C schinkii
# 2 Root; d__Bacteria; p__Actinobacteriota; c__Actinomycetia; o__Nanopelagicales; f__CAIYMF01; g__WLRQ01; s__WLRQ01 sp903918645
# 3 Root; d__Bacteria; p__Firmicutes_A; c__Clostridia; o__Lachnospirales; f__Lachnospiraceae; g__RGIG1934; s__RGIG1934 sp017396555

# %%
# Take marine7 as an example
# Read gold standard condensed
gs = fread('truths/marine7.condensed')[order(-coverage)]
gs[, taxonomy := gsub(';','; ',taxonomy)][, taxonomy := gsub('^','Root; ',taxonomy)]
sm = fread('output_singlem/singlem/marine7.profile')[order(-coverage)]
gs[1:3]

sm_species = sm[grep('s__', taxonomy)][order(-coverage)]
sm_species[1:3]
# Out:
#   sample        coverage
# 1 coverage7.tsv 134.5270
# 2 coverage7.tsv  92.0649
# 3 coverage7.tsv  75.6696
#   taxonomy
# 1 Root; d__Bacteria; p__Firmicutes_B; c__Desulfotomaculia; o__Desulfotomaculales; f__Pelotomaculaceae; g__Pelotomaculum_C; s__Pelotomaculum_C schinkii
# 2 Root; d__Bacteria; p__Actinobacteriota; c__Actinomycetia; o__Nanopelagicales; f__CAIYMF01; g__WLRQ01; s__WLRQ01 sp903918645
# 3 Root; d__Bacteria; p__Firmicutes_A; c__Clostridia; o__Lachnospirales; f__Lachnospiraceae; g__RGIG1934; s__RGIG1934 sp017396555
#   sample    coverage
# 1 marine7.1 135.56
# 2 marine7.1  88.34
# 3 marine7.1  36.09
#   taxonomy
# 1 Root; d__Bacteria; p__Firmicutes_B; c__Desulfotomaculia; o__Desulfotomaculales; f__Pelotomaculaceae; g__Pelotomaculum_C; s__Pelotomaculum_C schinkii
# 2 Root; d__Bacteria; p__Actinobacteriota; c__Actinomycetia; o__Nanopelagicales; f__CAIYMF01; g__WLRQ01; s__WLRQ01 sp903918645
# 3 Root; d__Bacteria; p__Firmicutes_A; c__Clostridia; o__Lachnospirales; f__Lachnospiraceae; g__RGIG1934; s__RGIG1934 sp017396555

# %%
# So just a coverage thing?
qplot(data=merge(gs, sm_species, by='taxonomy'), coverage.x, coverage.y)+geom_abline(intercept=0, slope=1)+xlim(c(0,5))+ylim(c(0,5))
m = merge(gs, sm_species, by='taxonomy', all.x=T)
m[is.na(coverage.y), coverage.y := 0]
qplot(data=m, coverage.x, coverage.y)+geom_abline(intercept=0, slope=1)+xlim(c(0,5))+ylim(c(0,5))
# Out:
# Warning message:
# “Removed 60 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# Warning message:
# “Removed 63 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# plot without title
# plot without title

# %% [markdown]
# # What does 0.35X coverage align to in terms of percent, for low abundance filtering?

# %%
mean_total_coverage = mean(truth_profiles2[, sum(true_coverage), by=community]$V1)

mean_total_coverage
0.35 / mean_total_coverage * 100
# Out:
# [1] 1704.973
# [1] 0.02052818

# %% [markdown]
# # Removing low abundance species improves things?

# %%
low_completeness = data.table(expand.grid(community=communities, tool_in=correct_taxonomy_tools))
low_completeness = low_completeness[,fread(paste('output_',tool_in,'/opal_low_abund/',community,'.opal_report', sep=''), sep='\t'), by=list(community,tool_in)]
low_completeness[1:3]
# Out:
# Error: File 'output_singlem/opal_low_abund/marine0.opal_report' does not exist or is non-readable. getwd()=='/mnt/hpccs01/work/microbiome/msingle/mess/176_singlem-benchmarking-clean/1_novel_strains'
# Traceback:
#
# 1. low_completeness[, fread(paste("output_", tool_in, "/opal_low_abund/",
#  .     community, ".opal_report", sep = ""), sep = "\t"), by = list(community,
#  .     tool_in)]
# 2. `[.data.table`(low_completeness, , fread(paste("output_", tool_in,
#  .     "/opal_low_abund/", community, ".opal_report", sep = ""),
#  .     sep = "\t"), by = list(community, tool_in))
# 3. fread(paste("output_", tool_in, "/opal_low_abund/", community,
#  .     ".opal_report", sep = ""), sep = "\t")
# 4. stopf("File '%s' does not exist or is non-readable. getwd()=='%s'",
#  .     file, getwd())
# 5. stop(gettextf(fmt, ..., domain = domain), domain = NA, call. = FALSE)

# %%
lc = low_completeness[tool!='Gold standard'][,.(value=mean(value)), by=list(metric,rank,tool_in)]
lc[, rank := factor(rank, levels=c('species','genus','family','order','class','phylum','kingdom'))]
lc[, tool2 := name_to_publication_name(tool_in, correct_taxonomy_only = T)]
# lc
# dcast(lc, rank+tool2~metric, value.var='value')
fwrite(x=dcast(lc, rank+tool2~metric, value.var='value'), file='supp_data_low_abundance.csv')

# %% [markdown]
# # Write overall results for supp data

# %%
d3w = d3[tool!='Gold standard'][,.(value=mean(value)), by=list(tool,metric,rank)]
d3w[, rank := factor(rank, levels=c('species','genus','family','order','class','phylum','kingdom'))]
d3w[, tool2 := name_to_publication_name(tool, correct_taxonomy_only = T)]
# dcast(d3w, rank+tool2~metric, value.var='value')
fwrite(x=dcast(d3w, rank+tool2~metric, value.var='value'), file='supp_data1.csv')

# %% [markdown]
# # Best performance in each category above species level

# %%
fwrite(d3[rank != 'species'][,mean(value),by=list(tool,metric)][order(metric,V1)])
# Out:
# tool,metric,V1
# singlem,Bray-Curtis distance,0.0262212512897523
# metaphlan,Bray-Curtis distance,0.0898918708615723
# kraken,Bray-Curtis distance,0.14572880337797
# sourmash,Bray-Curtis distance,0.160009495996787
# metabuli,Bray-Curtis distance,0.222472342531933
# sourmash,Completeness,0.763206875242464
# metabuli,Completeness,0.868982501776278
# metaphlan,Completeness,0.886584130376802
# kraken,Completeness,0.985590147944613
# singlem,Completeness,0.996651500517874
# metabuli,F1 score,0.536562297214841
# kraken,F1 score,0.742071391934547
# sourmash,F1 score,0.860757061761034
# metaphlan,F1 score,0.939099652030058
# singlem,F1 score,0.996307393458229
# singlem,False negatives,0.483333333333333
# kraken,False negatives,3.15
# metaphlan,False negatives,14.45
# metabuli,False negatives,24.2833333333333
# sourmash,False negatives,34.9166666666667
# metaphlan,False positives,0
# sourmash,False positives,0.0333333333333333
# singlem,False positives,0.2
# kraken,False positives,130.916666666667
# metabuli,False positives,464.116666666667
# metabuli,Jaccard index,0.419006344062043
# kraken,Jaccard index,0.612920973094099
# sourmash,Jaccard index,0.763136577787365
# metaphlan,Jaccard index,0.886584130376802
# singlem,Jaccard index,0.992712865676843
# singlem,L1 norm error,0.0517486609311326
# metaphlan,L1 norm error,0.179783741723145
# kraken,L1 norm error,0.291294710823905
# sourmash,L1 norm error,0.318727033844934
# metabuli,L1 norm error,0.434696634558094
# metabuli,Purity,0.430964282393284
# kraken,Purity,0.616273438531122
# singlem,Purity,0.996010387113721
# sourmash,Purity,0.999837677725118
# metaphlan,Purity,1
# metabuli,Shannon diversity,2.93617980561254
# sourmash,Shannon diversity,3.03741265652812
# kraken,Shannon diversity,3.10206230985526
# singlem,Shannon diversity,3.22776635711889
# metaphlan,Shannon diversity,3.25779242083828
# metabuli,Shannon equitability,0.493749277677564
# kraken,Shannon equitability,0.576962847062874
# singlem,Shannon equitability,0.68488965288231
# sourmash,Shannon equitability,0.692807594512802
# metaphlan,Shannon equitability,0.713797543755383
# metabuli,Sum of abundances,0.958863723166501
# singlem,Sum of abundances,0.978996760047947
# sourmash,Sum of abundances,0.99318615619792
# kraken,Sum of abundances,0.999050600000003
# metaphlan,Sum of abundances,1
# sourmash,Taxon counts,92.46
# metaphlan,Taxon counts,116.98
# singlem,Taxon counts,133.98
# kraken,Taxon counts,287.64
# metabuli,Taxon counts,662.12
# sourmash,True positives,77.35
# metabuli,True positives,87.9833333333333
# metaphlan,True positives,97.8166666666667
# kraken,True positives,109.116666666667
# singlem,True positives,111.783333333333
# metaphlan,Unweighted UniFrac (CAMI),610.9
# singlem,Unweighted UniFrac (CAMI),1080.8
# sourmash,Unweighted UniFrac (CAMI),1268.23883048847
# kraken,Unweighted UniFrac (CAMI),23534.882425
# metabuli,Unweighted UniFrac (CAMI),39035.5129759112
# metaphlan,Unweighted UniFrac error,0.151963627587827
# singlem,Unweighted UniFrac error,0.314195174429062
# sourmash,Unweighted UniFrac error,0.3360597594144
# kraken,Unweighted UniFrac error,6.78572971343059
# metabuli,Unweighted UniFrac error,11.3076681629815
# singlem,Weighted UniFrac (CAMI),0.594585128992872
# metaphlan,Weighted UniFrac (CAMI),1.51798452329006
# kraken,Weighted UniFrac (CAMI),2.25284255176355
# sourmash,Weighted UniFrac (CAMI),2.51387467986686
# metabuli,Weighted UniFrac (CAMI),4.06457223305627
# singlem,Weighted UniFrac error,0.00431651513431125
# metaphlan,Weighted UniFrac error,0.0120742732411759
# kraken,Weighted UniFrac error,0.0192388144648411
# sourmash,Weighted UniFrac error,0.0211040331476734
# metabuli,Weighted UniFrac error,0.0316152409941273
